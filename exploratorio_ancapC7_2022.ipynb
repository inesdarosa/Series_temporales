# %%
getwd()
setwd('G:/Mi unidad/ejercicios_proyectos/ancap/DATACHALLENGE 2022')

library(readr)
ancap_C7_22 <- read_csv('Desafio_Contenido_C7_Total_11-2017_09-2021.csv', col_names = TRUE)
str(ancap_C7_22)

attach(ancap_C7_22)
ancap_C7_22.ts <- ts(Contenido_C7_Total, start = c(2017, 317), freq = 365)
plot(ancap_C7_22.ts)
ancap_22.decomp <- plot(decompose(ancap_C7_22.ts))
# Out:
# [1] "G:/Mi unidad/ejercicios_proyectos/ancap/DATACHALLENGE 2022"
# Rows: 1049 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (1): archivo
# dbl  (1): Contenido_C7_Total
# date (1): Fecha
# time (1): Hora
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# spec_tbl_df [1,049 × 4] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ Fecha             : Date[1:1049], format: "2017-11-13" "2017-11-14" ...
#  $ Hora              : 'hms' num [1:1049] 07:55:00 07:00:00 07:00:00 07:00:00 ...
#   ..- attr(*, "units")= chr "secs"
#  $ Contenido_C7_Total: num [1:1049] 1.58 0.87 1.29 1.9 0.68 8.81 8.84 0.75 0.88 1.1 ...
# ...

# %%
acf(Contenido_C7_Total)$acf[2]
# Out:
# [1] 0.3925326
# Plot with title "Series  Contenido_C7_Total"
